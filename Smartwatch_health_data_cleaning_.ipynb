# %%
import pandas as pd

# %% [markdown]
# importing pandas as pd

# %%
df = pd.read_csv('/content/unclean_smartwatch_health_data (1).csv')

# %% [markdown]
# Reading Data Set

# %%
df.shape
# Out:
# (10000, 7)

# %% [markdown]
# Finding the rows and columns count

# %%
df.dtypes
# Out:
# User ID                   float64
# Heart Rate (BPM)          float64
# Blood Oxygen Level (%)    float64
# Step Count                float64
# Sleep Duration (hours)     object
# Activity Level             object
# Stress Level               object
# dtype: object

# %% [markdown]
# Checking Data Types

# %%
df['Sleep Duration (hours)']=pd.to_numeric(df['Sleep Duration (hours)'],errors='coerce')

# %% [markdown]
# Converting data type object into numeric type

# %%
df['Stress Level']=pd.to_numeric(df['Stress Level'],errors='coerce')

# %% [markdown]
# Converting data type object into numeric type

# %%
df.dtypes
# Out:
# User ID                   float64
# Heart Rate (BPM)          float64
# Blood Oxygen Level (%)    float64
# Step Count                float64
# Sleep Duration (hours)    float64
# Activity Level             object
# Stress Level              float64
# dtype: object

# %% [markdown]
# Rechecking the data type

# %%
df.describe()
# Out:
#            User ID  Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count  \
# count  9799.000000       9600.000000             9700.000000   9900.000000
# mean   3007.480253         76.035462               97.841581   6985.685885
# std    1150.581542         19.412483                1.732863   6885.809680
# min    1001.000000         40.000000               90.791208      0.910138
# 25%    1997.500000         64.890152               96.662683   2021.039657
# 50%    2998.000000         75.220601               98.010642   4962.534599
# 75%    4004.000000         85.198249               99.376179   9724.902880
# max    4999.000000        296.593970              100.000000  62486.690753
#
#        Stress Level
# count   9751.000000
# mean       5.464055
# std        2.871561
# min        1.000000
# 25%        3.000000
# 50%        5.000000
# 75%        8.000000
# max       10.000000

# %% [markdown]
# Finding statistical inference

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Finding duplicates

# %%
df.isnull().sum()
# Out:
# User ID                   201
# Heart Rate (BPM)          400
# Blood Oxygen Level (%)    300
# Step Count                100
# Sleep Duration (hours)    150
# Activity Level            200
# Stress Level              249
# dtype: int64

# %% [markdown]
# Finding Null values

# %%
df['User ID'].fillna(df['User ID'].mode()[0],inplace=True)
df
# Out:
# /tmp/ipython-input-21-1505260673.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['User ID'].fillna(df['User ID'].mode()[0],inplace=True)
#       User ID  Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count  \
# 0      4174.0         58.939776               98.809650   5450.390578
# 1      3708.0               NaN               98.532195    727.601610
# 2      1860.0        247.803052               97.052954   2826.521994
# 3      2294.0         40.000000               96.894213  13797.338044
# ...

# %% [markdown]
# Filling User ID column null values using mode()

# %%
df['Heart Rate (BPM)'].fillna(df['Heart Rate (BPM)'].mean(),inplace=True)
df
# Out:
# /tmp/ipython-input-22-1807548083.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Heart Rate (BPM)'].fillna(df['Heart Rate (BPM)'].mean(),inplace=True)
#       User ID  Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count  \
# 0      4174.0         58.939776               98.809650   5450.390578
# 1      3708.0         76.035462               98.532195    727.601610
# 2      1860.0        247.803052               97.052954   2826.521994
# ...

# %% [markdown]
# Filling Heart Rate (BPM) column null values using mean()

# %%
df['Blood Oxygen Level (%)'].fillna(df['Blood Oxygen Level (%)'].mean(),inplace=True)
df
# Out:
# /tmp/ipython-input-23-2385241741.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Blood Oxygen Level (%)'].fillna(df['Blood Oxygen Level (%)'].mean(),inplace=True)
#       User ID  Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count  \
# 0      4174.0         58.939776               98.809650   5450.390578
# 1      3708.0         76.035462               98.532195    727.601610
# 2      1860.0        247.803052               97.052954   2826.521994
# ...

# %% [markdown]
# Filling Blood Oxygen Level (%) column null values using mean()

# %%
df['Step Count'].fillna(df['Step Count'].mean(),inplace=True)
df
# Out:
# /tmp/ipython-input-25-387584320.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Step Count'].fillna(df['Step Count'].mean(),inplace=True)
#       User ID  Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count  \
# 0      4174.0         58.939776               98.809650   5450.390578
# 1      3708.0         76.035462               98.532195    727.601610
# 2      1860.0        247.803052               97.052954   2826.521994
# 3      2294.0         40.000000               96.894213  13797.338044
# ...

# %% [markdown]
# Filling Step Count column null values using mean()

# %%
df['Sleep Duration (hours)'].fillna(df['Sleep Duration (hours)'].mean(),inplace=True)
df
# Out:
# /tmp/ipython-input-39-680908751.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Sleep Duration (hours)'].fillna(df['Sleep Duration (hours)'].mean(),inplace=True)
#       User ID  Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count  \
# 0      4174.0         58.939776               98.809650   5450.390578
# 1      3708.0         76.035462               98.532195    727.601610
# 2      1860.0        247.803052               97.052954   2826.521994
# ...

# %% [markdown]
# Filling Sleep Duration (hours) column null values using mean()

# %%
df['Activity Level'].fillna(df['Activity Level'].mode()[0],inplace=True)
df
# Out:
# /tmp/ipython-input-40-383940140.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Activity Level'].fillna(df['Activity Level'].mode()[0],inplace=True)
#       User ID  Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count  \
# 0      4174.0         58.939776               98.809650   5450.390578
# 1      3708.0         76.035462               98.532195    727.601610
# 2      1860.0        247.803052               97.052954   2826.521994
# 3      2294.0         40.000000               96.894213  13797.338044
# ...

# %% [markdown]
# Filling Activity Level column null values using mode()

# %%
df['Stress Level'].fillna(df['Stress Level'].mean(),inplace=True)
df
# Out:
# /tmp/ipython-input-41-4144845162.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Stress Level'].fillna(df['Stress Level'].mean(),inplace=True)
#       User ID  Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count  \
# 0      4174.0         58.939776               98.809650   5450.390578
# 1      3708.0         76.035462               98.532195    727.601610
# 2      1860.0        247.803052               97.052954   2826.521994
# 3      2294.0         40.000000               96.894213  13797.338044
# ...

# %% [markdown]
# Filling Stress Level column null values using mean()
#
# ---

# %%
df.isnull().sum()
# Out:
# User ID                   0
# Heart Rate (BPM)          0
# Blood Oxygen Level (%)    0
# Step Count                0
# Sleep Duration (hours)    0
# Activity Level            0
# Stress Level              0
# dtype: int64

# %% [markdown]
# Rechecking null values

# %%
for x in df.index:
  if df.loc[x, "Heart Rate (BPM)"] > 120:
    df.loc[x, "Heart Rate (BPM)"] = 120

# %% [markdown]
# Fixing Heart Rate (BPM) column wrong values using logic

# %%
for x in df.index:
  if df.loc[x, "Sleep Duration (hours)"] < 1:
    df.loc[x, "Sleep Duration (hours)"] = 1

# %% [markdown]
# Fixing Sleep Duration (hours) column wrong values using logic

# %%
for x in df.index:
  if df.loc[x, "Step Count"] < 10:
    df.loc[x, "Step Count"] = 10

# %% [markdown]
# Fixing Step Count column wrong values using logic

# %%
print(df.to_string())
# Out:
#       User ID  Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count  Sleep Duration (hours) Activity Level  Stress Level
# 0      4174.0         58.939776               98.809650   5450.390578                7.167236  Highly Active      1.000000
# 1      3708.0         76.035462               98.532195    727.601610                6.538239  Highly_Active      5.000000
# 2      1860.0        120.000000               97.052954   2826.521994                6.505463  Highly Active      5.000000
# 3      2294.0         40.000000               96.894213  13797.338044                7.367790          Actve      3.000000
# 4      2130.0         61.950165               98.583797  15679.067648                6.505463  Highly_Active      6.000000
# 5      2095.0         96.285938               94.202910  10205.992256                8.378343  Highly_Active     10.000000
# 6      4772.0         47.272257               95.389760   3208.781177                7.871146     Seddentary      2.000000
# ...

# %% [markdown]
# Checking the data file

# %%
df.describe()
# Out:
#             User ID  Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count  \
# count  10000.000000      10000.000000            10000.000000  10000.000000
# mean    3021.560700         75.388979               97.841581   6985.691772
# std     1143.193956         14.764506                1.706669   6851.284668
# min     1001.000000         40.000000               90.791208     10.000000
# 25%     2016.000000         65.322796               96.703718   2037.300857
# 50%     3040.000000         76.035462               97.933416   5023.631772
# 75%     3985.000000         84.791711               99.327856   9680.097095
# max     4999.000000        120.000000              100.000000  62486.690753
#
#        Sleep Duration (hours)  Stress Level
# count            10000.000000  10000.000000
# mean                 6.505623      5.464055
# std                  1.479097      2.835581
# min                  1.000000      1.000000
# 25%                  5.541519      3.000000
# ...

# %% [markdown]
# Checking the statistical inference
